# %% [markdown]
# # Exploration Notebook to Compare USGS DOI Tool API to DataCite API
# Please be sure to review the other notebook in the GitHub repo before working with this notebook.

# %%
# https://support.datacite.org/docs/api-queries

# %%
import requests
import json
import pprint

# %%
# Queries by default search all fields, but a specific field can be provided in the query.
data_cite_query = requests.get('https://api.datacite.org/dois?query=10.5066')
json_data = json.loads(data_cite_query.text)
for iDOI in json_data['data']:
    pprint.pprint(iDOI)
# Out:
# {'attributes': {'container': None,
#                 'contentUrl': None,
#                 'contributors': None,
#                 'created': '2019-05-02T15:09:07.000Z',
#                 'creators': [{'familyName': 'Valentine',
#                               'givenName': 'Page C',
#                               'name': 'Valentine, Page C',
#                               'nameIdentifiers': [{'nameIdentifier': 'https://orcid.org/0000-0002-0485-6266',
#                                                    'nameIdentifierScheme': 'ORCID',
#                                                    'schemeUri': 'https://orcid.org'}],
#                               'nameType': 'Personal'},
#                              {'familyName': 'Cross',
#                               'givenName': 'VeeAnn A',
#                               'name': 'Cross, VeeAnn A',
#                               'nameIdentifiers': [{'nameIdentifier': 'https://orcid.org/0000-0002-9239-9009',
#                                                    'nameIdentifierScheme': 'ORCID',
#                                                    'schemeUri': 'https://orcid.org'}],
#                               'nameType': 'Personal'}],
#                 'dates': [{'date': '2017', 'dateType': 'Collected'},
#                           {'date': '2019', 'dateType': 'Issued'}],
#                 'descriptions': [{'description': 'This field activity is part '
#                                                  'of the effort to map '
#                                                  'geologic substrates of the '
#                                                  'Stellwagen Bank National '
#                                                  'Marine Sanctuary region off '
#                                                  'Boston, Massachusetts. The '
#                                                  'overall goal is to develop '
#                                                  'high-resolution (1:25,000) '
#                                                  'interpretive maps, based on '
#                                                  'multibeam sonar data and '
#                                                  'seabed sampling, showing '
#                                                  'surficial geology and seabed '
#                                                  'sediment dynamics. This '
#                                                  'cruise was conducted in '
#                                                  'collaboration with the '
#                                                  'Stellwagen Bank National '
#                                                  'Marine Sanctuary, and the '
#                                                  'data collected will aid '
#                                                  'research on the ecology of '
#                                                  'fish and invertebrate '
#                                                  'species that inhabit the '
#                                                  "region. The Sanctuary's "
#                                                  'research vessel, R/V Auk, '
#                                                  'visited 13 locations on '
#                                                  'Stellwagen Bank at which a '
#                                                  'customized Van Veen grab '
#                                                  'sampler (SEABOSS) equipped '
#                                                  'with a video camera and a '
#                                                  'CTD was deployed in drift '
#                                                  'mode to collect sediment for '
#                                                  'grain-size analysis, video '
#                                                  'imagery of the seabed, and '
#                                                  'measurements of water column '
#                                                  'properties.',
#                                   'descriptionType': 'Abstract'}],
#                 'doi': '10.5066/p9thizbb',
#                 'formats': None,
#                 'fundingReferences': None,
#                 'geoLocations': None,
#                 'identifiers': [{'identifier': 'https://doi.org/10.5066/p9thizbb',
#                                  'identifierType': 'DOI'}],
#                 'isActive': True,
#                 'language': None,
#                 'metadataVersion': 0,
#                 'publicationYear': 2019,
#                 'published': '2019',
#                 'publisher': 'U.S. Geological Survey',
#                 'reason': None,
#                 'registered': '2019-05-02T15:09:08.000Z',
#                 'relatedIdentifiers': None,
#                 'rightsList': None,
#                 'schemaVersion': None,
#                 'sizes': None,
#                 'source': 'mds',
#                 'state': 'findable',
#                 'subjects': None,
#                 'titles': [{'title': 'Sea Floor Sediment Samples, Seabed '
#                                      'Imagery, and CTD Water Column Data '
#                                      'Collected on Stellwagen Bank in January '
#                                      '2017, U.S. Geological Survey Field '
#                                      'Activity 2017-009-FA'}],
#                 'types': {'bibtex': 'misc',
#                           'citeproc': 'article',
#                           'resourceType': 'Collection',
#                           'resourceTypeGeneral': 'Collection',
#                           'ris': 'GEN',
#                           'schemaOrg': 'Collection'},
#                 'updated': '2019-05-02T15:09:08.000Z',
#                 'url': 'https://cmgds.marine.usgs.gov/data/field-activity-data/2017-009-FA/',
#                 'version': None},
#  'id': '10.5066/p9thizbb',
#  'relationships': {'client': {'data': {'id': 'usgs.prod', 'type': 'clients'}}},
#  'type': 'dois'}
# {'attributes': {'container': {},
#                 'contentUrl': None,
#                 'contributors': [],
#                 'created': '2018-11-30T18:49:44.000Z',
#                 'creators': [{'familyName': 'Clune',
#                               'givenName': 'John',
#                               'name': 'Clune, John',
#                               'nameIdentifiers': [{'nameIdentifier': 'https://orcid.org/0000-0002-3563-1975',
#                                                    'nameIdentifierScheme': 'ORCID'}],
#                               'nameType': 'Personal'}],
#                 'dates': [{'date': '2018', 'dateType': 'Issued'}],
#                 'descriptions': [{'description': 'This dataset contains the '
#                                                  'lithologic class and '
#                                                  'topographic position index '
#                                                  'information and '
#                                                  'quality-assurance and '
#                                                  'quality-control data not '
#                                                  'available in the online '
#                                                  'National Water Information '
#                                                  'System for 72 domestic wells '
#                                                  'sampled by the U.S. '
#                                                  'Geological Survey in '
#                                                  'Bradford County, '
#                                                  'Pennsylvania, May-August '
#                                                  '2016. The topographic '
#                                                  'position index (TPI) for '
#                                                  'each well location was '
#                                                  'computed on the basis of a '
#                                                  '25-meter digital elevation '
#                                                  'model (U.S. Geological '
#                                                  'Survey, 2009) using criteria '
#                                                  'reported by Llewellyn (2014) '
#                                                  'to indicate potential '
#                                                  'classes for topographic '
#                                                  'setting. The bedrock '
#                                                  'geologic unit and primary '
#                                                  'lithology were determined '
#                                                  'for each well location on '
#                                                  'the basis of the digital '
#                                                  'bedrock geologic map of '
#                                                  'Pennsylvania (Miles and '
#                                                  'Whitfield, 2001). The '
#                                                  'quality-assurance and '
#                                                  'quality-control data (such '
#                                                  'as blanks or replicates) '
#                                                  'were collected at a subset '
#                                                  'of sites to ensure that the '
#                                                  'data met specific '
#                                                  'data-quality objectives '
#                                                  'outlined for the study.',
#                                   'descriptionType': 'Abstract'}],
#                 'doi': '10.5066/p9vrv6us',
#                 'formats': [],
#                 'fundingReferences': [],
#                 'geoLocations': [],
#                 'identifiers': [{'identifier': 'https://doi.org/10.5066/p9vrv6us',
#                                  'identifierType': 'DOI'}],
#                 'isActive': True,
#                 'language': None,
#                 'metadataVersion': 0,
#                 'publicationYear': 2018,
#                 'published': '2018',
#                 'publisher': 'U.S. Geological Survey',
#                 'reason': None,
#                 'registered': '2018-11-30T18:49:45.000Z',
#                 'relatedIdentifiers': [],
#                 'rightsList': [],
#                 'schemaVersion': None,
#                 'sizes': [],
#                 'source': 'mds',
#                 'state': 'findable',
#                 'subjects': [{'subject': 'Geochemistry,Water Quality,Water '
#                                          'Resources'}],
#                 'titles': [{'title': 'Compilation of data not available in the '
#                                      'National Water Information System for '
#                                      'domestic wells sampled by the U.S. '
#                                      'Geological Survey in Bradford County, '
#                                      'Pennsylvania, May-August 2016'}],
#                 'types': {'bibtex': 'misc',
#                           'citeproc': 'dataset',
#                           'resourceType': 'Dataset',
#                           'resourceTypeGeneral': 'Dataset',
#                           'ris': 'DATA',
#                           'schemaOrg': 'Dataset'},
#                 'updated': '2019-05-02T14:32:15.000Z',
#                 'url': 'https://www.sciencebase.gov/catalog/item/5bec268fe4b0b3fc5cf913d4',
#                 'version': None},
#  'id': '10.5066/p9vrv6us',
#  'relationships': {'client': {'data': {'id': 'usgs.prod', 'type': 'clients'}}},
#  'type': 'dois'}
# {'attributes': {'container': None,
#                 'contentUrl': None,
#                 'contributors': None,
#                 'created': '2019-03-06T20:24:44.000Z',
#                 'creators': [{'familyName': 'Himmelstoss',
#                               'givenName': 'Emily',
#                               'name': 'Himmelstoss, Emily',
#                               'nameIdentifiers': [{'nameIdentifier': 'https://orcid.org/0000-0002-1760-5474',
#                                                    'nameIdentifierScheme': 'ORCID',
#                                                    'schemeUri': 'https://orcid.org'}],
#                               'nameType': 'Personal'},
#                              {'familyName': 'Farris',
#                               'givenName': 'Amy',
#                               'name': 'Farris, Amy',
#                               'nameIdentifiers': [{'nameIdentifier': 'https://orcid.org/0000-0002-4668-7261',
#                                                    'nameIdentifierScheme': 'ORCID',
#                                                    'schemeUri': 'https://orcid.org'}],
#                               'nameType': 'Personal'},
#                              {'familyName': 'Weber',
#                               'givenName': 'Kathryn M',
#                               'name': 'Weber, Kathryn M',
#                               'nameIdentifiers': [{'nameIdentifier': 'https://orcid.org/0000-0002-5498-7117',
#                                                    'nameIdentifierScheme': 'ORCID',
#                                                    'schemeUri': 'https://orcid.org'}],
#                               'nameType': 'Personal'},
#                              {'name': 'Henderson, Rachel (Contractor) E',
#                               'nameIdentifiers': [{'nameIdentifier': 'https://orcid.org/0000-0001-5810-7941',
#                                                    'nameIdentifierScheme': 'ORCID',
#                                                    'schemeUri': 'https://orcid.org'}],
#                               'nameType': 'Personal'}],
#                 'dates': [{'date': '2019', 'dateType': 'Issued'}],
#                 'descriptions': [{'description': 'The Massachusetts Office of '
#                                                  'Coastal Zone Management '
#                                                  'launched the Shoreline '
#                                                  'Change Project in 1989 to '
#                                                  'identify erosion-prone areas '
#                                                  'of the coast. The shoreline '
#                                                  'position and change rate are '
#                                                  'used to inform management '
#                                                  'decisions regarding the '
#                                                  'erosion of coastal '
#                                                  'resources. In 2001, a '
#                                                  'shoreline from 1994 was '
#                                                  'added to calculate both '
#                                                  'long- and short-term '
#                                                  'shoreline change rates along '
#                                                  'ocean-facing sections of the '
#                                                  'Massachusetts coast. In '
#                                                  '2013, two oceanfront '
#                                                  'shorelines for Massachusetts '
#                                                  'were added using 2008-9 '
#                                                  'color aerial orthoimagery '
#                                                  'and 2007 topographic lidar '
#                                                  'datasets obtained from the '
#                                                  'National Oceanic and '
#                                                  "Atmospheric Administration's "
#                                                  'Ocean Service, Coastal '
#                                                  'Services Center. This 2018 '
#                                                  'data release includes rates '
#                                                  'that incorporate two new '
#                                                  'mean high water (MHW) '
#                                                  'shorelines for the '
#                                                  'Massachusetts coast '
#                                                  'extracted from lidar data '
#                                                  'collected between 2010 and '
#                                                  '2014. The first new '
#                                                  'shoreline for the State '
#                                                  'includes data from 2010 '
#                                                  'along the North Shore and '
#                                                  'South Coast from lidar data '
#                                                  'collected by the U.S. Army '
#                                                  'Corps of Engineers (USACE) '
#                                                  'Joint Airborne Lidar '
#                                                  'Bathymetry Technical Center '
#                                                  'of Expertise. Shorelines '
#                                                  'along the South Shore and '
#                                                  'Outer Cape are from 2011 '
#                                                  'lidar data collected by the '
#                                                  "U.S. Geological Survey's "
#                                                  '(USGS) National Geospatial '
#                                                  'Program Office. Shorelines '
#                                                  "along Nantucket and Martha's "
#                                                  'Vineyard are from a 2012 '
#                                                  'USACE Post Sandy Topographic '
#                                                  'lidar survey. The second new '
#                                                  'shoreline for the North '
#                                                  'Shore, Boston, South Shore, '
#                                                  'Cape Cod Bay, Outer Cape, '
#                                                  'South Cape, Nantucket, '
#                                                  "Martha's Vineyard, and the "
#                                                  'South Coast (around Buzzards '
#                                                  'Bay to the Rhode Island '
#                                                  'Border) is from 2013-14 '
#                                                  'lidar data collected by the '
#                                                  '(USGS) Coastal and Marine '
#                                                  'Geology Program. This 2018 '
#                                                  'update of the rate of '
#                                                  'shoreline change in '
#                                                  'Massachusetts includes two '
#                                                  'types of rates. Some of the '
#                                                  'rates include a proxy-datum '
#                                                  'bias correction, this is '
#                                                  'indicated in the filename '
#                                                  'with "PDB". The rates that '
#                                                  'do not account for this '
#                                                  'correction have "NB" in '
#                                                  'their file names. The '
#                                                  'proxy-datum bias is applied '
#                                                  'because in some areas a '
#                                                  'proxy shoreline (like a High '
#                                                  'Water Line shoreline) has a '
#                                                  'bias when compared to a '
#                                                  'datum shoreline (like a Mean '
#                                                  'High Water shoreline). In '
#                                                  'areas where it exists, this '
#                                                  'bias should be accounted for '
#                                                  'when calculating rates using '
#                                                  'a mix of proxy and datum '
#                                                  'shorelines. This issue is '
#                                                  'explained further in '
#                                                  'Ruggiero and List (2009) and '
#                                                  'in the process steps of the '
#                                                  'metadata associated with the '
#                                                  'rates. This release includes '
#                                                  'both long-term (~150 years) '
#                                                  'and short term (~30 years) '
#                                                  'rates.  Files associated '
#                                                  'with the long-term rates '
#                                                  'have "LT" in their names, '
#                                                  'files associated with '
#                                                  'short-term rates have "ST" '
#                                                  'in their names.  References: '
#                                                  'Ruggerio, P., and List, '
#                                                  'J.H., 2009, Improving '
#                                                  'accuracy and statistical '
#                                                  'reliability of shoreline '
#                                                  'position and change rate '
#                                                  'estimates: Journal of '
#                                                  'Coastal Research, v. 25, no. '
#                                                  '5, p. 1069-1081. [Also '
#                                                  'available at '
#                                                  'https://doi.org/10.2112/08-1051.1]',
#                                   'descriptionType': 'Abstract'}],
#                 'doi': '10.5066/p9rrbeyk',
#                 'formats': None,
#                 'fundingReferences': None,
#                 'geoLocations': None,
#                 'identifiers': [{'identifier': 'https://doi.org/10.5066/p9rrbeyk',
#                                  'identifierType': 'DOI'}],
#                 'isActive': True,
#                 'language': None,
#                 'metadataVersion': 0,
#                 'publicationYear': 2019,
#                 'published': '2019',
#                 'publisher': 'U.S. Geological Survey',
#                 'reason': None,
#                 'registered': '2019-03-06T20:24:46.000Z',
#                 'relatedIdentifiers': None,
#                 'rightsList': None,
#                 'schemaVersion': None,
#                 'sizes': None,
#                 'source': 'mds',
#                 'state': 'findable',
#                 'subjects': [{'subject': 'Geomorphology'}],
#                 'titles': [{'title': 'Massachusetts Shoreline Change Project, '
#                                      '2018 Update: A GIS Compilation of '
#                                      'Shoreline Change Rates Calculated Using '
#                                      'Digital Shoreline Analysis System '
#                                      'Version 5.0, With Supplementary '
#                                      'Intersects and Baselines for '
#                                      'Massachusetts'}],
#                 'types': {'bibtex': 'misc',
#                           'citeproc': 'dataset',
#                           'resourceType': 'Dataset',
#                           'resourceTypeGeneral': 'Dataset',
#                           'ris': 'DATA',
#                           'schemaOrg': 'Dataset'},
#                 'updated': '2019-05-02T13:54:21.000Z',
#                 'url': 'https://www.sciencebase.gov/catalog/item/5be5857ce4b0b3fc5cf8c6ca',
#                 'version': None},
#  'id': '10.5066/p9rrbeyk',
#  'relationships': {'client': {'data': {'id': 'usgs.prod', 'type': 'clients'}}},
#  'type': 'dois'}
# {'attributes': {'container': None,
#                 'contentUrl': None,
#                 'contributors': None,
#                 'created': '2019-03-05T20:45:10.000Z',
#                 'creators': [{'familyName': 'Defne',
#                               'givenName': 'Zafer',
#                               'name': 'Defne, Zafer',
#                               'nameIdentifiers': [{'nameIdentifier': 'https://orcid.org/0000-0003-4544-4310',
#                                                    'nameIdentifierScheme': 'ORCID',
#                                                    'schemeUri': 'https://orcid.org'}],
#                               'nameType': 'Personal'},
#                              {'familyName': 'Ganju',
#                               'givenName': 'Neil Kamal',
#                               'name': 'Ganju, Neil Kamal',
#                               'nameIdentifiers': [{'nameIdentifier': 'https://orcid.org/0000-0002-1096-0465',
#                                                    'nameIdentifierScheme': 'ORCID',
#                                                    'schemeUri': 'https://orcid.org'}],
#                               'nameType': 'Personal'}],
#                 'dates': [{'date': '2019', 'dateType': 'Issued'}],
#                 'descriptions': [{'description': 'Biomass production is '
#                                                  'positively correlated with '
#                                                  'mean tidal range in salt '
#                                                  'marshes along the Atlantic '
#                                                  'coast of the United States '
#                                                  'of America. Recent studies '
#                                                  'support the idea that '
#                                                  'enhanced stability of the '
#                                                  'marshes can be attributed to '
#                                                  'increased vegetative growth '
#                                                  'due to increased tidal '
#                                                  'range. This dataset displays '
#                                                  'the spatial variation of '
#                                                  'mean tidal range (i.e. Mean '
#                                                  'Range of Tides, MN) in the '
#                                                  'Cape Cod National Seashore '
#                                                  '(CACO) salt marsh complex '
#                                                  'and approximal wetlands '
#                                                  'based on conceptual marsh '
#                                                  'units defined by Defne and '
#                                                  'Ganju (2019). MN was based '
#                                                  'on the calculated difference '
#                                                  'in height between mean high '
#                                                  'water (MHW) and mean low '
#                                                  'water (MLW) using the VDatum '
#                                                  '(v3.5) database ( '
#                                                  'http://vdatum.noaa.gov/ ). '
#                                                  'Through scientific efforts '
#                                                  'initiated with the Hurricane '
#                                                  'Sandy Science Plan, the U.S. '
#                                                  'Geological Survey has been '
#                                                  'expanding national '
#                                                  'assessment of coastal change '
#                                                  'hazards and forecast '
#                                                  'products to coastal '
#                                                  'wetlands. The intent is to '
#                                                  'provide federal, state, and '
#                                                  'local managers with tools to '
#                                                  'estimate their vulnerability '
#                                                  'and ecosystem service '
#                                                  'potential. For this purpose, '
#                                                  'the response and resilience '
#                                                  'of coastal wetlands to '
#                                                  'physical factors need to be '
#                                                  'assessed in terms of the '
#                                                  'ensuing change to their '
#                                                  'vulnerability and ecosystem '
#                                                  'services. CACO is one of the '
#                                                  'selected domains to expand '
#                                                  'this study.  References: '
#                                                  'Defne, Z., and Ganju, N.K., '
#                                                  '2019, Conceptual marsh units '
#                                                  'for Cape Cod National '
#                                                  'Seashore salt marsh complex, '
#                                                  'Massachusetts: U.S. '
#                                                  'Geological Survey data '
#                                                  'release, '
#                                                  'https://doi.org/10.5066/P955K1Y2.',
#                                   'descriptionType': 'Abstract'}],
#                 'doi': '10.5066/p9r7ppwb',
#                 'formats': None,
#                 'fundingReferences': None,
#                 'geoLocations': None,
#                 'identifiers': [{'identifier': 'https://doi.org/10.5066/p9r7ppwb',
#                                  'identifierType': 'DOI'}],
#                 'isActive': True,
#                 'language': None,
#                 'metadataVersion': 0,
#                 'publicationYear': 2019,
#                 'published': '2019',
#                 'publisher': 'U.S. Geological Survey',
#                 'reason': None,
#                 'registered': '2019-03-05T20:45:11.000Z',
#                 'relatedIdentifiers': None,
#                 'rightsList': None,
#                 'schemaVersion': None,
#                 'sizes': None,
#                 'source': 'mds',
#                 'state': 'findable',
#                 'subjects': [{'subject': 'Ecology,Geography,Remote Sensing'}],
#                 'titles': [{'title': 'Mean tidal range in marsh units of Cape '
#                                      'Cod National Seashore salt marsh '
#                                      'complex, Massachusetts'}],
#                 'types': {'bibtex': 'misc',
#                           'citeproc': 'dataset',
#                           'resourceType': 'Dataset',
#                           'resourceTypeGeneral': 'Dataset',
#                           'ris': 'DATA',
#                           'schemaOrg': 'Dataset'},
#                 'updated': '2019-05-02T13:53:37.000Z',
#                 'url': 'https://www.sciencebase.gov/catalog/item/5c62e48ce4b0fe48cb34c80c',
#                 'version': None},
#  'id': '10.5066/p9r7ppwb',
#  'relationships': {'client': {'data': {'id': 'usgs.prod', 'type': 'clients'}}},
#  'type': 'dois'}
# {'attributes': {'container': None,
#                 'contentUrl': None,
#                 'contributors': None,
#                 'created': '2018-11-26T20:19:17.000Z',
#                 'creators': [{'familyName': 'Weber',
#                               'givenName': 'Kathryn M',
#                               'name': 'Weber, Kathryn M',
#                               'nameIdentifiers': [{'nameIdentifier': 'https://orcid.org/0000-0002-5498-7117',
#                                                    'nameIdentifierScheme': 'ORCID',
#                                                    'schemeUri': 'https://orcid.org'}],
#                               'nameType': 'Personal'}],
#                 'dates': [{'date': '2018', 'dateType': 'Issued'}],
#                 'descriptions': [{'description': 'The Massachusetts Office of '
#                                                  'Coastal Zone Management '
#                                                  'launched the Shoreline '
#                                                  'Change Project in 1989 to '
#                                                  'identify erosion-prone areas '
#                                                  'of the coast. The shoreline '
#                                                  'position and change rate are '
#                                                  'used to inform management '
#                                                  'decisions regarding the '
#                                                  'erosion of coastal '
#                                                  'resources. In 2001, a 1994 '
#                                                  'shoreline was added to '
#                                                  'calculate both long- and '
#                                                  'short-term shoreline change '
#                                                  'rates at 40-meter intervals '
#                                                  'along ocean-facing sections '
#                                                  'of the Massachusetts coast. '
#                                                  'In 2013 two oceanfront '
#                                                  'shorelines for Massachusetts '
#                                                  'were added using 2008-2009 '
#                                                  'color aerial orthoimagery '
#                                                  'and 2007 topographic lidar '
#                                                  'datasets obtained from '
#                                                  "NOAA's Ocean Service, "
#                                                  'Coastal Services Center. '
#                                                  'This 2018 update includes '
#                                                  'two new mean high water '
#                                                  '(MHW) shorelines for the '
#                                                  'Massachusetts coast '
#                                                  'extracted from lidar data '
#                                                  'collected between 2010-2014. '
#                                                  'The first new shoreline for '
#                                                  'the state includes data from '
#                                                  '2010 along the North Shore '
#                                                  'and South Coast from lidar '
#                                                  'data collected by the U.S. '
#                                                  'Army Corps of Engineers '
#                                                  '(USACE) Joint Airborne Lidar '
#                                                  'Bathymetry Technical Center '
#                                                  'of Expertise (JALBTCX). '
#                                                  'Shorelines along the South '
#                                                  'Shore and Outer Cape are '
#                                                  'from 2011 lidar data '
#                                                  'collected by the U.S. '
#                                                  "Geological Survey's (USGS) "
#                                                  'National Geospatial Program '
#                                                  'Office. Shorelines along '
#                                                  "Nantucket and Martha's "
#                                                  'Vineyard are from a 2012 '
#                                                  'U.S. Army Corps of Engineers '
#                                                  'Post Sandy Topographic lidar '
#                                                  'survey. The second new '
#                                                  'shoreline for the North '
#                                                  'Shore, Boston, South Shore, '
#                                                  'Cape Cod Bay, Outer Cape, '
#                                                  'South Cape, Nantucket, '
#                                                  "Martha's Vineyard, and South "
#                                                  'Coast west of Buzzards Bay '
#                                                  'is from 2013-2014 lidar data '
#                                                  'collected by the U.S. '
#                                                  "Geological Survey's (USGS) "
#                                                  'Coastal and Marine Geology '
#                                                  'Program. Shorelines were '
#                                                  'extracted from these lidar '
#                                                  'surveys using several '
#                                                  'different methods dependent '
#                                                  'on the location of the '
#                                                  'shoreline and whether or not '
#                                                  'wave data were available.',
#                                   'descriptionType': 'Abstract'}],
#                 'doi': '10.5066/p9o7s72b',
#                 'formats': None,
#                 'fundingReferences': None,
#                 'geoLocations': None,
#                 'identifiers': [{'identifier': 'https://doi.org/10.5066/p9o7s72b',
#                                  'identifierType': 'DOI'}],
#                 'isActive': True,
#                 'language': None,
#                 'metadataVersion': 1,
#                 'publicationYear': 2018,
#                 'published': '2018',
#                 'publisher': 'U.S. Geological Survey',
#                 'reason': None,
#                 'registered': '2018-11-26T20:19:19.000Z',
#                 'relatedIdentifiers': None,
#                 'rightsList': None,
#                 'schemaVersion': None,
#                 'sizes': None,
#                 'source': 'mds',
#                 'state': 'findable',
#                 'subjects': [{'subject': 'Ecology,Geomorphology'}],
#                 'titles': [{'title': 'Massachusetts Shoreline Change Project: '
#                                      'A GIS Compilation of Vector Shorelines '
#                                      'for the 2018 update'}],
#                 'types': {'bibtex': 'misc',
#                           'citeproc': 'dataset',
#                           'resourceType': 'Dataset',
#                           'resourceTypeGeneral': 'Dataset',
#                           'ris': 'DATA',
#                           'schemaOrg': 'Dataset'},
#                 'updated': '2019-05-02T13:52:58.000Z',
#                 'url': 'https://www.sciencebase.gov/catalog/item/5bcde5dce4b0f0758fc178d0',
#                 'version': None},
#  'id': '10.5066/p9o7s72b',
#  'relationships': {'client': {'data': {'id': 'usgs.prod', 'type': 'clients'}}},
#  'type': 'dois'}
# {'attributes': {'container': None,
#                 'contentUrl': None,
#                 'contributors': None,
#                 'created': '2019-03-05T21:01:28.000Z',
#                 'creators': [{'familyName': 'Defne',
#                               'givenName': 'Zafer',
#                               'name': 'Defne, Zafer',
#                               'nameIdentifiers': [{'nameIdentifier': 'https://orcid.org/0000-0003-4544-4310',
#                                                    'nameIdentifierScheme': 'ORCID',
#                                                    'schemeUri': 'https://orcid.org'}],
#                               'nameType': 'Personal'},
#                              {'familyName': 'Ganju',
#                               'givenName': 'Neil Kamal',
#                               'name': 'Ganju, Neil Kamal',
#                               'nameIdentifiers': [{'nameIdentifier': 'https://orcid.org/0000-0002-1096-0465',
#                                                    'nameIdentifierScheme': 'ORCID',
#                                                    'schemeUri': 'https://orcid.org'}],
#                               'nameType': 'Personal'}],
#                 'dates': [{'date': '2019', 'dateType': 'Issued'}],
#                 'descriptions': [{'description': 'Unvegetated to vegetated '
#                                                  'marsh ratio (UVVR) in the '
#                                                  'Cape Cod National Seashore '
#                                                  '(CACO) salt marsh complex '
#                                                  'and approximal wetlands is '
#                                                  'computed based on conceptual '
#                                                  'marsh units defined by Defne '
#                                                  'and Ganju (2019). UVVR was '
#                                                  'calculated based on U.S. '
#                                                  'Department of Agriculture '
#                                                  'National Agriculture Imagery '
#                                                  'Program (NAIP) 1-meter '
#                                                  'resolution imagery. Through '
#                                                  'scientific efforts initiated '
#                                                  'with the Hurricane Sandy '
#                                                  'Science Plan, the U.S. '
#                                                  'Geological Survey has been '
#                                                  'expanding national '
#                                                  'assessment of coastal change '
#                                                  'hazards and forecast '
#                                                  'products to coastal '
#                                                  'wetlands. The intent is to '
#                                                  'provide federal, state, and '
#                                                  'local managers with tools to '
#                                                  'estimate their vulnerability '
#                                                  'and ecosystem service '
#                                                  'potential. For this purpose, '
#                                                  'the response and resilience '
#                                                  'of coastal wetlands to '
#                                                  'physical factors need to be '
#                                                  'assessed in terms of the '
#                                                  'ensuing change to their '
#                                                  'vulnerability and ecosystem '
#                                                  'services. CACO is one of the '
#                                                  'selected domains to expand '
#                                                  'this study.\r\n'
#                                                  '\r\n'
#                                                  'References: Defne, Z., and '
#                                                  'Ganju, N.K., 2019, '
#                                                  'Conceptual marsh units for '
#                                                  'Cape Cod National Seashore '
#                                                  'salt marsh complex, '
#                                                  'Massachusetts: U.S. '
#                                                  'Geological Survey data '
#                                                  'release, '
#                                                  'https://doi.org/10.5066/P955K1Y2.',
#                                   'descriptionType': 'Abstract'}],
#                 'doi': '10.5066/p99ku0c5',
#                 'formats': None,
#                 'fundingReferences': None,
#                 'geoLocations': None,
#                 'identifiers': [{'identifier': 'https://doi.org/10.5066/p99ku0c5',
#                                  'identifierType': 'DOI'}],
#                 'isActive': True,
#                 'language': None,
#                 'metadataVersion': 0,
#                 'publicationYear': 2019,
#                 'published': '2019',
#                 'publisher': 'U.S. Geological Survey',
#                 'reason': None,
#                 'registered': '2019-03-05T21:01:30.000Z',
#                 'relatedIdentifiers': None,
#                 'rightsList': None,
#                 'schemaVersion': None,
#                 'sizes': None,
#                 'source': 'mds',
#                 'state': 'findable',
#                 'subjects': [{'subject': 'Ecology,Geography,Remote Sensing'}],
#                 'titles': [{'title': 'Unvegetated to vegetated marsh ratio in '
#                                      'Cape Cod National Seashore salt marsh '
#                                      'complex, Massachusetts'}],
#                 'types': {'bibtex': 'misc',
#                           'citeproc': 'dataset',
#                           'resourceType': 'Dataset',
#                           'resourceTypeGeneral': 'Dataset',
#                           'ris': 'DATA',
#                           'schemaOrg': 'Dataset'},
#                 'updated': '2019-05-02T13:52:08.000Z',
#                 'url': 'https://www.sciencebase.gov/catalog/item/5c62f414e4b0fe48cb34c8b9',
#                 'version': None},
#  'id': '10.5066/p99ku0c5',
#  'relationships': {'client': {'data': {'id': 'usgs.prod', 'type': 'clients'}}},
#  'type': 'dois'}
# {'attributes': {'container': None,
#                 'contentUrl': None,
#                 'contributors': None,
#                 'created': '2019-03-22T15:30:34.000Z',
#                 'creators': [{'familyName': 'Brothers',
#                               'givenName': 'Laura',
#                               'name': 'Brothers, Laura',
#                               'nameIdentifiers': [{'nameIdentifier': 'https://orcid.org/0000-0003-2986-5166',
#                                                    'nameIdentifierScheme': 'ORCID',
#                                                    'schemeUri': 'https://orcid.org'}],
#                               'nameType': 'Personal'},
#                              {'familyName': 'Ruppel',
#                               'givenName': 'Carolyn',
#                               'name': 'Ruppel, Carolyn',
#                               'nameIdentifiers': [{'nameIdentifier': 'https://orcid.org/0000-0003-2284-6632',
#                                                    'nameIdentifierScheme': 'ORCID',
#                                                    'schemeUri': 'https://orcid.org'}],
#                               'nameType': 'Personal'},
#                              {'familyName': 'Hart',
#                               'givenName': 'Patrick E',
#                               'name': 'Hart, Patrick E',
#                               'nameIdentifiers': [{'nameIdentifier': 'https://orcid.org/0000-0002-5080-1426',
#                                                    'nameIdentifierScheme': 'ORCID',
# ...
#                                                  'studies of nearshore coastal '
#                                                  'dynamics along Sandwich Town '
#                                                  'Neck Beach, MA. Data '
#                                                  'collection equipment used '
#                                                  'for this investigation are '
#                                                  'mounted on an unmanned '
#                                                  'surface vehicle (USV) '
#                                                  'uniquely adapted from a '
#                                                  'commercially sold '
#                                                  'gas-powered kayak and termed '
#                                                  'the "jetyak". The jetyak '
#                                                  'design is the result of a '
#                                                  'collaborative effort between '
#                                                  'USGS and Woods Hole '
#                                                  'Oceanographic Institution '
#                                                  '(WHOI) scientists.',
#                                   'descriptionType': 'Abstract'}],
#                 'doi': '10.5066/p9tjim2m',
#                 'formats': None,
#                 'fundingReferences': None,
#                 'geoLocations': None,
#                 'identifiers': [{'identifier': 'https://doi.org/10.5066/p9tjim2m',
#                                  'identifierType': 'DOI'}],
#                 'isActive': True,
#                 'language': None,
#                 'metadataVersion': 2,
#                 'publicationYear': 2018,
#                 'published': '2018',
#                 'publisher': 'U.S. Geological Survey',
#                 'reason': None,
#                 'registered': '2018-08-13T20:46:38.000Z',
#                 'relatedIdentifiers': None,
#                 'rightsList': None,
#                 'schemaVersion': None,
#                 'sizes': None,
#                 'source': 'mds',
#                 'state': 'findable',
#                 'subjects': None,
#                 'titles': [{'title': 'Sidescan sonar, single beam bathymetry, '
#                                      'and navigation collected offshore of '
#                                      'Sandwich Beach in 2016, U.S. Geological '
#                                      'Field Activity 2016-030-FA'}],
#                 'types': {'bibtex': 'misc',
#                           'citeproc': 'article',
#                           'resourceType': 'Collection',
#                           'resourceTypeGeneral': 'Collection',
#                           'ris': 'GEN',
#                           'schemaOrg': 'Collection'},
#                 'updated': '2019-05-02T13:33:35.000Z',
#                 'url': 'https://cmgds.marine.usgs.gov/data/field-activity-data/2016-030-FA/',
#                 'version': None},
#  'id': '10.5066/p9tjim2m',
#  'relationships': {'client': {'data': {'id': 'usgs.prod', 'type': 'clients'}}},
#  'type': 'dois'}
# {'attributes': {'container': {},
#                 'contentUrl': None,
#                 'contributors': [],
#                 'created': '2018-07-05T19:33:54.000Z',
#                 'creators': [{'familyName': 'Luoma',
#                               'givenName': 'James A',
#                               'name': 'Luoma, James A',
#                               'nameIdentifiers': [{'nameIdentifier': 'https://orcid.org/0000-0003-3556-0190',
#                                                    'nameIdentifierScheme': 'ORCID'}],
#                               'nameType': 'Personal'},
#                              {'familyName': 'Severson',
#                               'givenName': 'Todd J',
#                               'name': 'Severson, Todd J',
#                               'nameIdentifiers': [{'nameIdentifier': 'https://orcid.org/0000-0001-5282-3779',
#                                                    'nameIdentifierScheme': 'ORCID'}],
#                               'nameType': 'Personal'},
#                              {'familyName': 'Wise',
#                               'givenName': 'Jeremy K',
#                               'name': 'Wise, Jeremy K',
#                               'nameIdentifiers': [{'nameIdentifier': 'https://orcid.org/0000-0003-0184-6959',
#                                                    'nameIdentifierScheme': 'ORCID'}],
#                               'nameType': 'Personal'},
#                              {'familyName': 'Barbour',
#                               'givenName': 'Matthew T',
#                               'name': 'Barbour, Matthew T',
#                               'nameIdentifiers': [{'nameIdentifier': 'https://orcid.org/0000-0002-0095-9188',
#                                                    'nameIdentifierScheme': 'ORCID'}],
#                               'nameType': 'Personal'}],
#                 'dates': [{'date': '2018', 'dateType': 'Created'},
#                           {'date': '2018', 'dateType': 'Issued'}],
#                 'descriptions': [{'description': 'Two SAS code files were used '
#                                                  'to analyze data for this '
#                                                  'study and they included: \r\n'
#                                                  '1) code to compare the '
#                                                  'condition of unique cohorts '
#                                                  'of zebra mussel test animals '
#                                                  'at 3 time points '
#                                                  '(pre-exposure, exposure '
#                                                  'termination, and '
#                                                  'post-exposure termination), '
#                                                  'and  \r\n'
#                                                  '2) code to predict the '
#                                                  'lethal concentration of test '
#                                                  'articles required to cause '
#                                                  '50 and 99% mortality (LC50 '
#                                                  'and LC99, respectively) for '
#                                                  'each toxicant, exposure '
#                                                  'duration, and temperature '
#                                                  'combination.',
#                                   'descriptionType': 'Abstract'}],
#                 'doi': '10.5066/p9qvaxcm',
#                 'formats': ['Other'],
#                 'fundingReferences': [],
#                 'geoLocations': [],
#                 'identifiers': [{'identifier': 'https://doi.org/10.5066/p9qvaxcm',
#                                  'identifierType': 'DOI'}],
#                 'isActive': True,
#                 'language': None,
#                 'metadataVersion': 0,
#                 'publicationYear': 2018,
#                 'published': '2018',
#                 'publisher': 'U.S. Geological Survey',
#                 'reason': None,
#                 'registered': '2018-07-05T19:33:55.000Z',
#                 'relatedIdentifiers': [],
#                 'rightsList': [],
#                 'schemaVersion': None,
#                 'sizes': [],
#                 'source': None,
#                 'state': 'findable',
#                 'subjects': [{'subject': 'zebra mussel, SAS'}],
#                 'titles': [{'title': 'Effects of temperature and exposure '
#                                      'duration on four potential '
#                                      'rapid-response tools for zebra mussel '
#                                      '(Dreissena polymorpha) eradication: '
#                                      'Code'}],
#                 'types': {'bibtex': 'misc',
#                           'citeproc': 'article',
#                           'resourceType': 'Model',
#                           'resourceTypeGeneral': 'Model',
#                           'ris': 'GEN',
#                           'schemaOrg': 'CreativeWork'},
#                 'updated': '2019-05-02T13:13:27.000Z',
#                 'url': 'https://www.sciencebase.gov/catalog/item/5b3e71c9e4b060350a0efcb7',
#                 'version': None},
#  'id': '10.5066/p9qvaxcm',
#  'relationships': {'client': {'data': {'id': 'usgs.prod', 'type': 'clients'}}},
#  'type': 'dois'}
# {'attributes': {'container': {},
#                 'contentUrl': None,
#                 'contributors': [],
#                 'created': '2018-10-26T22:46:42.000Z',
#                 'creators': [{'familyName': 'Bradley',
#                               'givenName': 'Paul M.',
#                               'name': 'Bradley, Paul M.',
#                               'nameIdentifiers': [{'nameIdentifier': 'https://orcid.org/0000-0001-7522-8606',
#                                                    'nameIdentifierScheme': 'ORCID'}],
#                               'nameType': 'Personal'},
#                              {'familyName': 'Romanok',
#                               'givenName': 'Kristin M.',
#                               'name': 'Romanok, Kristin M.',
#                               'nameIdentifiers': [{'nameIdentifier': 'https://orcid.org/0000-0002-8472-8765',
#                                                    'nameIdentifierScheme': 'ORCID'}],
#                               'nameType': 'Personal'}],
#                 'dates': [{'date': '2018', 'dateType': 'Issued'}],
#                 'descriptions': [{'description': 'Chemical and biological '
#                                                  'concentration results, '
#                                                  'quality assurance and '
#                                                  'quality control and '
#                                                  'statistical summaries from '
#                                                  '26 tapwater samples, '
#                                                  'collected from paired '
#                                                  'residential and work place '
#                                                  'sites in 11 states in 2016. '
#                                                  'Samples were analylzed at '
#                                                  'U.S. Geological Survey and '
#                                                  'U.S. Environmental '
#                                                  'Protection Agency '
#                                                  'laboratories.',
#                                   'descriptionType': 'Abstract'}],
#                 'doi': '10.5066/f7959gvj',
#                 'formats': [],
#                 'fundingReferences': [],
#                 'geoLocations': [],
#                 'identifiers': [{'identifier': 'https://doi.org/10.5066/f7959gvj',
#                                  'identifierType': 'DOI'}],
#                 'isActive': True,
#                 'language': None,
#                 'metadataVersion': 0,
#                 'publicationYear': 2018,
#                 'published': '2018',
#                 'publisher': 'U.S. Geological Survey',
#                 'reason': None,
#                 'registered': '2018-10-26T22:46:43.000Z',
#                 'relatedIdentifiers': [],
#                 'rightsList': [],
#                 'schemaVersion': None,
#                 'sizes': [],
#                 'source': 'mds',
#                 'state': 'findable',
#                 'subjects': [{'subject': 'Environmental Health'}],
#                 'titles': [{'title': 'Target-Chemical Concentrations, Exposure '
#                                      'Activity Ratios, and Bioassay Results '
#                                      'for Assessment of '
#                                      'Mixed-Organic/Inorganic-Chemical '
#                                      'Exposure in USA Tapwater, 2016'}],
#                 'types': {'bibtex': 'misc',
#                           'citeproc': 'dataset',
#                           'resourceType': 'Dataset',
#                           'resourceTypeGeneral': 'Dataset',
#                           'ris': 'DATA',
#                           'schemaOrg': 'Dataset'},
#                 'updated': '2019-05-02T12:30:55.000Z',
#                 'url': 'https://www.sciencebase.gov/catalog/item/5ab3d60be4b081f61ab5e3d4',
#                 'version': None},
#  'id': '10.5066/f7959gvj',
#  'relationships': {'client': {'data': {'id': 'usgs.prod', 'type': 'clients'}}},
#  'type': 'dois'}
# {'attributes': {'container': {},
#                 'contentUrl': None,
#                 'contributors': [],
#                 'created': '2018-08-29T20:35:29.000Z',
#                 'creators': [{'familyName': 'Prior-Magee',
#                               'givenName': 'Julie',
#                               'name': 'Prior-Magee, Julie',
#                               'nameIdentifiers': [{'nameIdentifier': 'https://orcid.org/0000-0003-4031-1885',
#                                                    'nameIdentifierScheme': 'ORCID'}],
#                               'nameType': 'Personal'},
#                              {'familyName': 'McKerrow',
#                               'givenName': 'Alexa',
#                               'name': 'McKerrow, Alexa',
#                               'nameIdentifiers': [{'nameIdentifier': 'https://orcid.org/0000-0002-8312-2905',
#                                                    'nameIdentifierScheme': 'ORCID'}],
#                               'nameType': 'Personal'}],
#                 'dates': [{'date': '2018', 'dateType': 'Created'},
#                           {'date': '2018', 'dateType': 'Issued'}],
#                 'descriptions': [{'description': 'This dataset represents a '
#                                                  'species habitat distribution '
#                                                  'model for Red-bellied '
#                                                  'Mudsnake.  These habitat '
#                                                  'maps are created by applying '
#                                                  'a deductive habitat model to '
#                                                  'remotely-sensed data layers '
#                                                  "within a species' range.",
#                                   'descriptionType': 'Abstract'}],
#                 'doi': '10.5066/f7qf8r9s',
#                 'formats': [],
#                 'fundingReferences': [],
#                 'geoLocations': [],
#                 'identifiers': [{'identifier': 'https://doi.org/10.5066/f7qf8r9s',
#                                  'identifierType': 'DOI'}],
#                 'isActive': True,
#                 'language': None,
#                 'metadataVersion': 0,
#                 'publicationYear': 2018,
#                 'published': '2018',
#                 'publisher': 'U.S. Geological Survey',
#                 'reason': None,
#                 'registered': '2018-08-29T20:36:31.000Z',
#                 'relatedIdentifiers': [],
#                 'rightsList': [],
#                 'schemaVersion': None,
#                 'sizes': [],
#                 'source': 'mds',
#                 'state': 'findable',
#                 'subjects': [{'subject': 'USGS Data Release'}],
#                 'titles': [{'title': 'Red-bellied Mudsnake (Farancia abacura) '
#                                      'rRBMUx_CONUS_2001v1 Habitat Map'}],
#                 'types': {'bibtex': 'misc',
#                           'citeproc': 'article',
#                           'resourceType': 'Model',
#                           'resourceTypeGeneral': 'Model',
#                           'ris': 'GEN',
#                           'schemaOrg': 'CreativeWork'},
#                 'updated': '2019-05-02T10:33:11.000Z',
#                 'url': 'https://www.sciencebase.gov/catalog/item/58fe21ede4b0f87f0854ae50',
#                 'version': None},
#  'id': '10.5066/f7qf8r9s',
#  'relationships': {'client': {'data': {'id': 'usgs.prod', 'type': 'clients'}}},
#  'type': 'dois'}

# %%
data_cite_query = requests.get('https://api.datacite.org/dois?provider-id=usgs')
data_cite_query.text
# Out:
# '{"data":[{"id":"10.5066/p9vrv6us","type":"dois","attributes":{"doi":"10.5066/p9vrv6us","identifiers":[{"identifier":"https://doi.org/10.5066/p9vrv6us","identifierType":"DOI"}],"creators":[{"name":"Clune, John","nameType":"Personal","givenName":"John","familyName":"Clune","nameIdentifiers":[{"nameIdentifier":"https://orcid.org/0000-0002-3563-1975","nameIdentifierScheme":"ORCID"}]}],"titles":[{"title":"Compilation of data not available in the National Water Information System for domestic wells sampled by the U.S. Geological Survey in Bradford County, Pennsylvania, May-August 2016"}],"publisher":"U.S. Geological Survey","container":{},"publicationYear":2018,"subjects":[{"subject":"Geochemistry,Water Quality,Water Resources"}],"contributors":[],"dates":[{"date":"2018","dateType":"Issued"}],"language":null,"types":{"ris":"DATA","bibtex":"misc","citeproc":"dataset","schemaOrg":"Dataset","resourceType":"Dataset","resourceTypeGeneral":"Dataset"},"relatedIdentifiers":[],"sizes":[],"formats":[],"version":null,"rightsList":[],"descriptions":[{"description":"This dataset contains the lithologic class and topographic position index information and quality-assurance and quality-control data not available in the online National Water Information System for 72 domestic wells sampled by the U.S. Geological Survey in Bradford County, Pennsylvania, May-August 2016. The topographic position index (TPI) for each well location was computed on the basis of a 25-meter digital elevation model (U.S. Geological Survey, 2009) using criteria reported by Llewellyn (2014) to indicate potential classes for topographic setting. The bedrock geologic unit and primary lithology were determined for each well location on the basis of the digital bedrock geologic map of Pennsylvania (Miles and Whitfield, 2001). The quality-assurance and quality-control data (such as blanks or replicates) were collected at a subset of sites to ensure that the data met specific data-quality objectives outlined for the study.","descriptionType":"Abstract"}],"geoLocations":[],"fundingReferences":[],"url":"https://www.sciencebase.gov/catalog/item/5bec268fe4b0b3fc5cf913d4","contentUrl":null,"metadataVersion":0,"schemaVersion":null,"source":"mds","isActive":true,"state":"findable","reason":null,"created":"2018-11-30T18:49:44.000Z","registered":"2018-11-30T18:49:45.000Z","published":"2018","updated":"2019-05-02T14:32:15.000Z"},"relationships":{"client":{"data":{"id":"usgs.prod","type":"clients"}}}},{"id":"10.5066/p9rrbeyk","type":"dois","attributes":{"doi":"10.5066/p9rrbeyk","identifiers":[{"identifier":"https://doi.org/10.5066/p9rrbeyk","identifierType":"DOI"}],"creators":[{"name":"Himmelstoss, Emily","nameType":"Personal","givenName":"Emily","familyName":"Himmelstoss","nameIdentifiers":[{"schemeUri":"https://orcid.org","nameIdentifier":"https://orcid.org/0000-0002-1760-5474","nameIdentifierScheme":"ORCID"}]},{"name":"Farris, Amy","nameType":"Personal","givenName":"Amy","familyName":"Farris","nameIdentifiers":[{"schemeUri":"https://orcid.org","nameIdentifier":"https://orcid.org/0000-0002-4668-7261","nameIdentifierScheme":"ORCID"}]},{"name":"Weber, Kathryn M","nameType":"Personal","givenName":"Kathryn M","familyName":"Weber","nameIdentifiers":[{"schemeUri":"https://orcid.org","nameIdentifier":"https://orcid.org/0000-0002-5498-7117","nameIdentifierScheme":"ORCID"}]},{"name":"Henderson, Rachel (Contractor) E","nameType":"Personal","nameIdentifiers":[{"schemeUri":"https://orcid.org","nameIdentifier":"https://orcid.org/0000-0001-5810-7941","nameIdentifierScheme":"ORCID"}]}],"titles":[{"title":"Massachusetts Shoreline Change Project, 2018 Update: A GIS Compilation of Shoreline Change Rates Calculated Using Digital Shoreline Analysis System Version 5.0, With Supplementary Intersects and Baselines for Massachusetts"}],"publisher":"U.S. Geological Survey","container":null,"publicationYear":2019,"subjects":[{"subject":"Geomorphology"}],"contributors":null,"dates":[{"date":"2019","dateType":"Issue ...

# %% [markdown]
# ## Compare response from DataCite to USGS DOI tool

# %% [markdown]
# ### DataCite API

# %%
#Not caps senstive, note available fields
datacite_query = requests.get('https://api.datacite.org/dois?query=10.5066/p9vrv6us')
datacite_json = json.loads(datacite_query.text)
datacite_json['data'][0]
# Out:
# {'id': '10.5066/p9vrv6us',
#  'type': 'dois',
#  'attributes': {'doi': '10.5066/p9vrv6us',
#   'identifiers': [{'identifier': 'https://doi.org/10.5066/p9vrv6us',
#     'identifierType': 'DOI'}],
#   'creators': [{'name': 'Clune, John',
#     'nameType': 'Personal',
#     'givenName': 'John',
#     'familyName': 'Clune',
#     'nameIdentifiers': [{'nameIdentifier': 'https://orcid.org/0000-0002-3563-1975',
#       'nameIdentifierScheme': 'ORCID'}]}],
#   'titles': [{'title': 'Compilation of data not available in the National Water Information System for domestic wells sampled by the U.S. Geological Survey in Bradford County, Pennsylvania, May-August 2016'}],
#   'publisher': 'U.S. Geological Survey',
#   'container': {},
#   'publicationYear': 2018,
#   'subjects': [{'subject': 'Geochemistry,Water Quality,Water Resources'}],
#   'contributors': [],
#   'dates': [{'date': '2018', 'dateType': 'Issued'}],
#   'language': None,
#   'types': {'ris': 'DATA',
#    'bibtex': 'misc',
#    'citeproc': 'dataset',
#    'schemaOrg': 'Dataset',
#    'resourceType': 'Dataset',
#    'resourceTypeGeneral': 'Dataset'},
#   'relatedIdentifiers': [],
#   'sizes': [],
#   'formats': [],
#   'version': None,
#   'rightsList': [],
#   'descriptions': [{'description': 'This dataset contains the lithologic class and topographic position index information and quality-assurance and quality-control data not available in the online National Water Information System for 72 domestic wells sampled by the U.S. Geological Survey in Bradford County, Pennsylvania, May-August 2016. The topographic position index (TPI) for each well location was computed on the basis of a 25-meter digital elevation model (U.S. Geological Survey, 2009) using criteria reported by Llewellyn (2014) to indicate potential classes for topographic setting. The bedrock geologic unit and primary lithology were determined for each well location on the basis of the digital bedrock geologic map of Pennsylvania (Miles and Whitfield, 2001). The quality-assurance and quality-control data (such as blanks or replicates) were collected at a subset of sites to ensure that the data met specific data-quality objectives outlined for the study.',
#     'descriptionType': 'Abstract'}],
#   'geoLocations': [],
#   'fundingReferences': [],
#   'url': 'https://www.sciencebase.gov/catalog/item/5bec268fe4b0b3fc5cf913d4',
#   'contentUrl': None,
#   'metadataVersion': 0,
#   'schemaVersion': None,
#   'source': 'mds',
#   'isActive': True,
#   'state': 'findable',
#   'reason': None,
#   'created': '2018-11-30T18:49:44.000Z',
#   'registered': '2018-11-30T18:49:45.000Z',
#   'published': '2018',
#   'updated': '2019-05-02T14:32:15.000Z'},
#  'relationships': {'client': {'data': {'id': 'usgs.prod', 'type': 'clients'}}}}

# %%
x = datacite_json['data'][0]
x.keys()
# Out:
# dict_keys(['id', 'type', 'attributes', 'relationships'])

# %%
x = datacite_json['data'][0]['attributes']
for key in x:
    print (key)
# Out:
# doi
# identifiers
# creators
# titles
# publisher
# container
# publicationYear
# subjects
# contributors
# dates
# language
# types
# relatedIdentifiers
# sizes
# formats
# version
# rightsList
# descriptions
# geoLocations
# fundingReferences
# url
# contentUrl
# metadataVersion
# schemaVersion
# source
# isActive
# state
# reason
# created
# registered
# published
# updated

# %% [markdown]
# ### USGS Data Tools DOI API

# %%
import getpass
from usgs_datatools import doi

#DoiSession = doi.DoiSession(env='production')  # Production
#DoiSession = doi.DoiSession(env='staging')  # Staging
#*Note: User must be on the USGS network or VPN to successfully use the staging environment.*
DoiSession = doi.DoiSession(env='production')

# %%
username = 'dignizio@usgs.gov'
password = getpass.getpass('USGS AD Password: ')
print('*Complete*')
# Out:
# USGS AD Password: ········
# *Complete*

# %%
DoiSession.doi_authenticate(username, password)
print ("Successfully authenticated.")
# Out:
# Successfully authenticated.

# %%
# Note the raw URL being accessed under the hood with the function.
# This is worth noting when comparing to the documentation for REST endpoint.
# ('https://www1.usgs.gov/csas/dmapi/doi/doi:10.5066/P9VRV6US') Caps sensitive. Uses colon.
usgs_doi = DoiSession.get_doi('doi:10.5066/F7W0944J')
usgs_doi
# Out:
# {'doi': 'doi:10.5066/F7W0944J',
#  'title': 'North American Breeding Bird Survey Dataset 1966 - 2016, version 2016.0',
#  'pubDate': '2017',
#  'url': 'ftp://ftpext.usgs.gov/pub/er/md/laurel/BBS/Archivefiles/Version2016v0/',
#  'resourceType': 'Dataset',
#  'date': '1966/2016',
#  'dateType': 'Collected',
#  'description': 'The 1966-2016 North American Breeding Bird Survey dataset contains avian point count data for more than 700 North American bird taxa (primarily species, but also some races and unidentified species groupings).  These data are collected annually during the breeding season, primarily June and May, along thousands of randomly established roadside survey routes in the United States and Canada. Routes are about 24.5 miles (39.2 km) long with counting locations placed at regular intervals, for a total of 50 stops. At each stop, a person highly skilled in avian identification conducts a 3-minute point count, recording every bird seen within a quarter-mile (400-m) radius and every bird heard.  Surveys begin 30 minutes before local sunrise and take approximately 5 hours to complete.  A route is sampled once per year, with the total number of routes sampled per year growing over time; about 600 routes were sampled in 1966, while in recent decades approximately 3000 routes have been sampled annually.  In addition to avian count data, this dataset also contains date route sampled, survey start and end times, start and end weather conditions, a unique observer identification number, route identification information, route location information including geographic coordinates of route start point, and an indicator of sample quality.',
#  'subject': 'North American bird population data; relative abundance and distribution information for approx. 600 species',
#  'username': 'kpardieck@usgs.gov',
#  'status': 'public',
#  'noDataReleaseAvailableReason': 'APPROVED_AT_CENTER',
#  'noPublicationIdAvailable': True,
#  'dataSourceId': 17193,
#  'dataSourceName': 'Patuxent Wildlife Research Center',
#  'linkCheckingStatus': 'TIMED OUT 20190425',
#  'formatTypes': ['csv'],
#  'authors': [{'authorName': 'Hudson, Marie-Anne R.',
#    'orcId': '',
#    'nameType': 'Personal',
#    'position': 0},
#   {'authorName': 'Lutmerding, Michael',
#    'orcId': '',
#    'nameType': 'Personal',
#    'position': 1},
#   {'authorName': 'Campbell, Kate',
#    'orcId': '',
#    'nameType': 'Personal',
#    'position': 2},
#   {'authorName': 'Pardieck, Keith L.',
#    'orcId': '',
#    'nameType': 'Personal',
#    'position': 3},
#   {'authorName': 'Ziolkowski Jr., David',
#    'orcId': '0000-0002-2500-4417',
#    'nameType': 'Personal',
#    'position': 4}],
#  'users': ['kpardieck@usgs.gov', 'dziolkowski@usgs.gov'],
#  'relatedIdentifiers': [{'relatedIdentifier': 'https://doi.org/10.5066/F76972V8',
#    'dataciteRelationType': 'IS_PREVIOUS_VERSION_OF',
#    'usgsRelationSubType': None}],
#  'ipdsNumbers': [],
#  'created': '2018-05-02',
#  'modified': '2019-04-18'}

# %%
for field in usgs_doi.keys():
    print (field)
# Out:
# doi
# title
# pubDate
# url
# resourceType
# date
# dateType
# description
# subject
# username
# status
# noDataReleaseAvailableReason
# noPublicationIdAvailable
# dataSourceId
# dataSourceName
# linkCheckingStatus
# formatTypes
# authors
# users
# relatedIdentifiers
# ipdsNumbers
# created
# modified
