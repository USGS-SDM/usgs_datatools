# %% [markdown]
# ### An easy wrapper for the SIPP API

# %%
from usgs_datatools import basis

# %%
basis.usgs_centers().head()
# Out:
#   Active AllocationOrganizationGroup CostCenterGroup  \
# 0      N                          00          GG0000
# 1      Y                          RA          GGCMRA
# 2      Y                          RB          GGCMRB
# 3      N                          RC          GGCMRC
# 4      N                          RD          GGCMRD
#
#               CostCenterGroupName MissionArea RegionCode SalesOfficeCode WMA  \
# 0             Unknown Cost Center                     XX            G000   N
# 1                OFC REG EXEC, SW                     SW            GCRA   N
# 2              FT COLLINS SCI CTR         ECO         SW            GCRB   N
# 3    CENTRAL REGION DRILLING UNIT         WMA         SW            GCRC   Y
# 4  CENTRAL REG DRILLING UNIT- WCF         WMA         RM            GCRD   Y
#
#   WSC
# 0   N
# 1   N
# 2   N
# 3   N
# 4   N

# %% [markdown]
# #### But you can also filter the results right out the gate

# %%
basis.usgs_centers(RegionCode='SW', MissionArea='ECO')
# Out:
#     Active AllocationOrganizationGroup CostCenterGroup  \
# 2        Y                          RB          GGCMRB
# 20       Y                          ZD          GGCMZD
# 211      N                          ZD          GGWSZD
#
#               CostCenterGroupName MissionArea RegionCode SalesOfficeCode WMA  \
# 2              FT COLLINS SCI CTR         ECO         SW            GCRB   N
# 20   SW BIOLOGICAL SCIENCE CENTER         ECO         SW            GCZD   N
# 211  SW BIOLOGICAL SCIENCE CENTER         ECO         SW            GWZD   N
#
#     WSC
# 2     N
# 20    N
# 211   N

# %% [markdown]
#    #### The only other function I've added is the center master list

# %%
basis.center_master_list(cost_center='GGCMRB').head()
# Out:
#           ProjectChief    ProjectChiefEmail ProjectCostCenter  \
# 0      Lamb, Berton L.       lambl@usgs.gov        GGCMRB0000
# 1  VanGelder, Ellen M.  vangeldere@usgs.gov        GGCMRB0000
# 2      Lamb, Berton L.       lambl@usgs.gov        GGCMRB0000
# 3    Stevens, Patricia    stevensp@usgs.gov        GGCMRB0000
# 4    Stevens, Patricia    stevensp@usgs.gov        GGCMRB0000
#
#   ProjectCostCenterName ProjectEndDate ProjectID ProjectNumber  \
# 0    FT COLLINS SCI CTR     2007-09-30      1038       RB0099O
# 1    FT COLLINS SCI CTR     2007-09-30      1045       RB009R5
# 2    FT COLLINS SCI CTR     2006-09-30      1057       RB0097W
# 3    FT COLLINS SCI CTR     2010-09-30      1145       RB00999
# 4    FT COLLINS SCI CTR     2007-12-14      1146       RB009NA
#
#   ProjectStartDate ProjectStatus  \
# 0       2002-10-01      Approved
# 1       1991-10-01        Active
# 2       2002-10-01      Approved
# 3       2000-10-01      Approved
# 4       1989-06-01      Approved
#
# ...
